# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ast import literal_eval
import warnings
warnings.filterwarnings('ignore')

# %%
# paths
ga__TSP_22__curves = "../selected_results/ga__TSP_22__curves.csv"
ga__TSP_5__curves = "../selected_results/ga__TSP_5__curves.csv"
ga__TSP_22__curves = "../selected_results/ga__TSP_22__curves.csv"
ga__TSP_5__curves = "../selected_results/ga__TSP_5__curves.csv"
ga__TSP_22__curves = "../selected_results/ga__TSP_22__curves.csv"
ga__TSP_14__curves = "../selected_results/ga__TSP_14__curves.csv"
mimic__TSP_22__curves = "../selected_results/mimic__TSP_22__curves.csv"
mimic__TSP_5__curves = "../selected_results/mimic__TSP_5__curves.csv"
mimic__TSP_14__curves = "../selected_results/mimic__TSP_14__curves.csv"
rhc__TSP_22__curves = "../selected_results/rhc__TSP_22__curves.csv"
rhc__TSP_5__curves = "../selected_results/rhc__TSP_5__curves.csv"
rhc__TSP_22__curves = "../selected_results/rhc__TSP_22__curves.csv"
rhc__TSP_5__curves = "../selected_results/rhc__TSP_5__curves.csv"
rhc__TSP_22__curves = "../selected_results/rhc__TSP_22__curves.csv"
rhc__TSP_14__curves = "../selected_results/rhc__TSP_14__curves.csv"
sa__TSP_22__curves = "../selected_results/sa__TSP_22__curves.csv"
sa__TSP_5__curves = "../selected_results/sa__TSP_5__curves.csv"
sa__TSP_22__curves = "../selected_results/sa__TSP_22__curves.csv"
sa__TSP_5__curves = "../selected_results/sa__TSP_5__curves.csv"
sa__TSP_22__curves = "../selected_results/sa__TSP_22__curves.csv"
sa__TSP_14__curves = "../selected_results/sa__TSP_14__curves.csv"

# %%
ga__TSP_22_df = pd.read_csv(ga__TSP_22__curves, index_col="column0").reset_index(drop=True)
ga__TSP_5_df = pd.read_csv(ga__TSP_5__curves, index_col="column0").reset_index(drop=True)
ga__TSP_22_df = pd.read_csv(ga__TSP_22__curves, index_col="column0").reset_index(drop=True)
ga__TSP_5_df = pd.read_csv(ga__TSP_5__curves, index_col="column0").reset_index(drop=True)
ga__TSP_14_df = pd.read_csv(ga__TSP_14__curves, index_col="column0").reset_index(drop=True)
mimic__TSP_22_df = pd.read_csv(mimic__TSP_22__curves, index_col="column0").reset_index(drop=True)
mimic__TSP_5_df = pd.read_csv(mimic__TSP_5__curves, index_col="column0").reset_index(drop=True)
mimic__TSP_14_df = pd.read_csv(mimic__TSP_14__curves, index_col="column0").reset_index(drop=True)
rhc__TSP_22_df = pd.read_csv(rhc__TSP_22__curves, index_col="column0").reset_index(drop=True)
rhc__TSP_5_df = pd.read_csv(rhc__TSP_5__curves, index_col="column0").reset_index(drop=True)
rhc__TSP_22_df = pd.read_csv(rhc__TSP_22__curves, index_col="column0").reset_index(drop=True)
rhc__TSP_5_df = pd.read_csv(rhc__TSP_5__curves, index_col="column0").reset_index(drop=True)
rhc__TSP_14_df = pd.read_csv(rhc__TSP_14__curves, index_col="column0").reset_index(drop=True)
sa__TSP_22_df = pd.read_csv(sa__TSP_22__curves, index_col="column0").reset_index(drop=True)
sa__TSP_5_df = pd.read_csv(sa__TSP_5__curves, index_col="column0").reset_index(drop=True)
sa__TSP_22_df = pd.read_csv(sa__TSP_22__curves, index_col="column0").reset_index(drop=True)
sa__TSP_5_df = pd.read_csv(sa__TSP_5__curves, index_col="column0").reset_index(drop=True)
sa__TSP_14_df = pd.read_csv(sa__TSP_14__curves, index_col="column0").reset_index(drop=True)

# %%
sa__TSP_5_df['Fitness']
# Out:
# 0       532.390429
# 1       532.390429
# 2       532.390429
# 3       532.390429
# 4       527.489408
#            ...
# 5001    498.235144
# 5002    498.235144
# 5003    498.235144
# 5004    498.235144
# 5005    498.235144
# Name: Fitness, Length: 5006, dtype: float64

# %%
sa__ = "SA"
ga__ = "GA"
rhc__ = "RHC"
mimic__ = "MIMIC"

# %%
plt.figure()
lw = 1
plt.plot(rhc__TSP_22_df['Iteration'], rhc__TSP_22_df['Fitness'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__TSP_22_df['Iteration'], sa__TSP_22_df['Fitness'], label=sa__, color='blue',lw=0.5)
plt.plot(ga__TSP_22_df['Iteration'], ga__TSP_22_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__TSP_22_df['Iteration'], mimic__TSP_22_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Iteration')
plt.ylabel('Fitness')
plt.xlim(0,2000)
plt.title("Traveling Salesperson (size=22)")
plt.legend(loc="upper right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__TSP_22_df['FEvals'], rhc__TSP_22_df['Fitness'], label=rhc__, color='orange',lw=0.1)
plt.plot(sa__TSP_22_df['FEvals'], sa__TSP_22_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__TSP_22_df['FEvals'], ga__TSP_22_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__TSP_22_df['FEvals'], mimic__TSP_22_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Function Evals')
plt.ylabel('Fitness')
plt.xlim(0,60000)
# plt.ylim(0,2500)
plt.title("Traveling Salesperson (size=22)")
plt.legend(loc="upper right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__TSP_22_df['FEvals'], rhc__TSP_22_df['Fitness'], label=rhc__, color='orange',lw=0.1)
plt.plot(sa__TSP_22_df['FEvals'], sa__TSP_22_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__TSP_22_df['FEvals'], ga__TSP_22_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__TSP_22_df['FEvals'], mimic__TSP_22_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Function Evals')
plt.ylabel('Fitness')
# plt.xlim(0,3500)
# plt.ylim(150,220)
plt.title("Traveling Salesperson F.Evals - zoom (size=22)")
plt.legend(loc="upper right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__TSP_22_df['Time'], rhc__TSP_22_df['Fitness'], label=rhc__, color='orange',lw=1)
plt.plot(sa__TSP_22_df['Time'], sa__TSP_22_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__TSP_22_df['Time'], ga__TSP_22_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__TSP_22_df[(mimic__TSP_22_df['Time'] != 0)]['Time'], mimic__TSP_22_df[(mimic__TSP_22_df['Time'] != 0)]['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Time')
plt.ylabel('Fitness')
plt.xlim(0,15)
# plt.ylim(150,220)
plt.title("Traveling Salesperson Time - zoom (size=22)")
plt.legend(loc="upper right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__TSP_22_df['Time'], rhc__TSP_22_df['FEvals'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__TSP_22_df['Time'], sa__TSP_22_df['FEvals'], label=sa__, color='blue',lw=lw)
plt.plot(ga__TSP_22_df['Time'], ga__TSP_22_df['FEvals'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__TSP_22_df[(mimic__TSP_22_df['Time'] != 0)]['Time'], mimic__TSP_22_df[(mimic__TSP_22_df['Time'] != 0)]['FEvals'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Time')
plt.ylabel('Function Evals')
# plt.xlim(0,10)
# plt.ylim(0,5500)
plt.title("Traveling Salesperson F.Evals/Time (size=22)")
plt.legend(loc="upper right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__TSP_14_df['FEvals'], rhc__TSP_14_df['Fitness'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__TSP_14_df['FEvals'], sa__TSP_14_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__TSP_14_df['FEvals'], ga__TSP_14_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__TSP_14_df['FEvals'], mimic__TSP_14_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Function Evals')
plt.ylabel('Fitness')
# plt.xlim(0,28000)
# plt.ylim(400,680)
plt.title("Traveling Salesperson F.Evals (size=14)")
plt.legend(loc="upper right")
