# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ast import literal_eval
import warnings
warnings.filterwarnings('ignore')

# %%
# paths
ga__Knapsack_10__curves = "selected_results/ga__Knapsack_10__curves.csv"
ga__Knapsack_5__curves = "selected_results/ga__Knapsack_5__curves.csv"
ga__TSP_22__curves = "selected_results/ga__TSP_22__curves.csv"
ga__TSP_5__curves = "selected_results/ga__TSP_5__curves.csv"
ga__continuous_peaks30__curves = "selected_results/ga__continuous_peaks30__curves.csv"
ga__continuous_peaks__curves = "selected_results/ga__continuous_peaks__curves.csv"
mimic__Knapsack_10__curves = "selected_results/mimic__Knapsack_10__curves.csv"
mimic__Knapsack_5__curves = "selected_results/mimic__Knapsack_5__curves.csv"
mimic__TSP_22__curves = "selected_results/mimic__TSP_22__curves.csv"
mimic__TSP_5__curves = "selected_results/mimic__TSP_5__curves.csv"
mimic__continuous_peaks30__curves = "selected_results/mimic__continuous_peaks30__curves.csv"
mimic__continuous_peaks__curves = "selected_results/mimic__continuous_peaks__curves.csv"
rhc__Knapsack_10__curves = "selected_results/rhc__Knapsack_10__curves.csv"
rhc__Knapsack_5__curves = "selected_results/rhc__Knapsack_5__curves.csv"
rhc__TSP_22__curves = "selected_results/rhc__TSP_22__curves.csv"
rhc__TSP_5__curves = "selected_results/rhc__TSP_5__curves.csv"
rhc__continuous_peaks30__curves = "selected_results/rhc__continuous_peaks30__curves.csv"
rhc__continuous_peaks__curves = "selected_results/rhc__continuous_peaks__curves.csv"
sa__Knapsack_10__curves = "selected_results/sa__Knapsack_10__curves.csv"
sa__Knapsack_5__curves = "selected_results/sa__Knapsack_5__curves.csv"
sa__TSP_22__curves = "selected_results/sa__TSP_22__curves.csv"
sa__TSP_5__curves = "selected_results/sa__TSP_5__curves.csv"
sa__continuous_peaks30__curves = "selected_results/sa__continuous_peaks30__curves.csv"
sa__continuous_peaks__curves = "selected_results/sa__continuous_peaks__curves.csv"

# %%
ga__Knapsack_10_df = pd.read_csv(ga__Knapsack_10__curves, index_col="column0").reset_index(drop=True)
ga__Knapsack_5_df = pd.read_csv(ga__Knapsack_5__curves, index_col="column0").reset_index(drop=True)
ga__TSP_22_df = pd.read_csv(ga__TSP_22__curves, index_col="column0").reset_index(drop=True)
ga__TSP_5_df = pd.read_csv(ga__TSP_5__curves, index_col="column0").reset_index(drop=True)
ga__continuous_peaks30_df = pd.read_csv(ga__continuous_peaks30__curves, index_col="column0").reset_index(drop=True)
ga__continuous_peaks_df = pd.read_csv(ga__continuous_peaks__curves, index_col="column0").reset_index(drop=True)
mimic__Knapsack_10_df = pd.read_csv(mimic__Knapsack_10__curves, index_col="column0").reset_index(drop=True)
mimic__Knapsack_5_df = pd.read_csv(mimic__Knapsack_5__curves, index_col="column0").reset_index(drop=True)
mimic__TSP_22_df = pd.read_csv(mimic__TSP_22__curves, index_col="column0").reset_index(drop=True)
mimic__TSP_5_df = pd.read_csv(mimic__TSP_5__curves, index_col="column0").reset_index(drop=True)
mimic__continuous_peaks30_df = pd.read_csv(mimic__continuous_peaks30__curves, index_col="column0").reset_index(drop=True)
mimic__continuous_peaks_df = pd.read_csv(mimic__continuous_peaks__curves, index_col="column0").reset_index(drop=True)
rhc__Knapsack_10_df = pd.read_csv(rhc__Knapsack_10__curves, index_col="column0").reset_index(drop=True)
rhc__Knapsack_5_df = pd.read_csv(rhc__Knapsack_5__curves, index_col="column0").reset_index(drop=True)
rhc__TSP_22_df = pd.read_csv(rhc__TSP_22__curves, index_col="column0").reset_index(drop=True)
rhc__TSP_5_df = pd.read_csv(rhc__TSP_5__curves, index_col="column0").reset_index(drop=True)
rhc__continuous_peaks30_df = pd.read_csv(rhc__continuous_peaks30__curves, index_col="column0").reset_index(drop=True)
rhc__continuous_peaks_df = pd.read_csv(rhc__continuous_peaks__curves, index_col="column0").reset_index(drop=True)
sa__Knapsack_10_df = pd.read_csv(sa__Knapsack_10__curves, index_col="column0").reset_index(drop=True)
sa__Knapsack_5_df = pd.read_csv(sa__Knapsack_5__curves, index_col="column0").reset_index(drop=True)
sa__TSP_22_df = pd.read_csv(sa__TSP_22__curves, index_col="column0").reset_index(drop=True)
sa__TSP_5_df = pd.read_csv(sa__TSP_5__curves, index_col="column0").reset_index(drop=True)
sa__continuous_peaks30_df = pd.read_csv(sa__continuous_peaks30__curves, index_col="column0").reset_index(drop=True)
sa__continuous_peaks_df = pd.read_csv(sa__continuous_peaks__curves, index_col="column0").reset_index(drop=True)

# %%
sa__continuous_peaks_df['Fitness']
# Out:
# 0       24.0
# 1       25.0
# 2       25.0
# 3       25.0
# 4       24.0
#         ...
# 5104    37.0
# 5105    37.0
# 5106    37.0
# 5107    37.0
# 5108    37.0
# Name: Fitness, Length: 5109, dtype: float64

# %%
sa__ = "SA"
ga__ = "GA"
rhc__ = "RHC"
mimic__ = "MIMIC"

# %%
plt.figure()
lw = 1
plt.plot(rhc__continuous_peaks_df['Iteration'], rhc__continuous_peaks_df['Fitness'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__continuous_peaks_df['Iteration'], sa__continuous_peaks_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__continuous_peaks_df['Iteration'], ga__continuous_peaks_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__continuous_peaks_df['Iteration'], mimic__continuous_peaks_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Iteration')
plt.ylabel('Fitness')
plt.title("Continuous Peaks (size=20)")
plt.legend(loc="lower right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__continuous_peaks_df['Iteration'], rhc__continuous_peaks_df['Fitness'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__continuous_peaks_df['Iteration'], sa__continuous_peaks_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__continuous_peaks_df['Iteration'], ga__continuous_peaks_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__continuous_peaks_df['Iteration'], mimic__continuous_peaks_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Iteration')
plt.ylabel('Fitness')
# plt.xlim(0,300)
# plt.ylim(20,40)
plt.title("Continuous Peaks (size=20)")
plt.legend(loc="lower right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__continuous_peaks_df['Iteration'], rhc__continuous_peaks_df['Fitness'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__continuous_peaks_df['Iteration'], sa__continuous_peaks_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__continuous_peaks_df['Iteration'], ga__continuous_peaks_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__continuous_peaks_df['Iteration'], mimic__continuous_peaks_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Iteration')
plt.ylabel('Fitness')
plt.xlim(0,200)
plt.ylim(15,40)
plt.title("Continuous Peaks (size=20)")
plt.legend(loc="lower right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__continuous_peaks_df['FEvals'], rhc__continuous_peaks_df['Fitness'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__continuous_peaks_df['FEvals'], sa__continuous_peaks_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__continuous_peaks_df['FEvals'], ga__continuous_peaks_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__continuous_peaks_df['FEvals'], mimic__continuous_peaks_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Function Evals')
plt.ylabel('Fitness')
# plt.xlim(0,300)
# plt.ylim(20,40)
plt.title("Continuous Peaks (size=20)")
plt.legend(loc="lower right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__continuous_peaks_df['FEvals'], rhc__continuous_peaks_df['Fitness'], label=rhc__, color='orange',lw=0.1)
plt.plot(sa__continuous_peaks_df['FEvals'], sa__continuous_peaks_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__continuous_peaks_df['FEvals'], ga__continuous_peaks_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__continuous_peaks_df['FEvals'], mimic__continuous_peaks_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Function Evals')
plt.ylabel('Fitness')
plt.xlim(0,3000)
plt.ylim(20,40)
plt.title("Continuous Peaks F.Evals (size=20)")
plt.legend(loc="lower right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__continuous_peaks_df['Time'], rhc__continuous_peaks_df['Fitness'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__continuous_peaks_df['Time'], sa__continuous_peaks_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__continuous_peaks_df['Time'], ga__continuous_peaks_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__continuous_peaks_df['Time'], mimic__continuous_peaks_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Time')
plt.ylabel('Fitness')
plt.xlim(0,0.3)
plt.ylim(20,40)
plt.title("Continuous Peaks Time (size=20)")
plt.legend(loc="lower right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__continuous_peaks_df['Time'], rhc__continuous_peaks_df['FEvals'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__continuous_peaks_df['Time'], sa__continuous_peaks_df['FEvals'], label=sa__, color='blue',lw=lw)
plt.plot(ga__continuous_peaks_df['Time'], ga__continuous_peaks_df['FEvals'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__continuous_peaks_df['Time'], mimic__continuous_peaks_df['FEvals'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Time')
plt.ylabel('Function Evals')
plt.xlim(0,3)
plt.ylim(0,30000)
plt.title("Continuous Peaks F.Evals/Time (size=20)")
plt.legend(loc="lower right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__continuous_peaks30_df['FEvals'], rhc__continuous_peaks30_df['Fitness'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__continuous_peaks30_df['FEvals'], sa__continuous_peaks30_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__continuous_peaks30_df['FEvals'], ga__continuous_peaks30_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__continuous_peaks30_df['FEvals'], mimic__continuous_peaks30_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Function Evals')
plt.ylabel('Fitness')
plt.xlim(0,15000)
plt.ylim(30,60)
plt.title("Continuous Peaks F.Evals (size=30)")
plt.legend(loc="lower right")
