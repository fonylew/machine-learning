# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ast import literal_eval
import warnings
warnings.filterwarnings('ignore')

# %%
# paths
ga__Knapsack_10__curves = "../selected_results/ga__Knapsack_10__curves.csv"
ga__Knapsack_5__curves = "../selected_results/ga__Knapsack_5__curves.csv"
ga__TSP_22__curves = "../selected_results/ga__TSP_22__curves.csv"
ga__TSP_5__curves = "../selected_results/ga__TSP_5__curves.csv"
ga__Knapsack_10__curves = "../selected_results/ga__Knapsack_10__curves.csv"
ga__Knapsack_5__curves = "../selected_results/ga__Knapsack_5__curves.csv"
mimic__Knapsack_10__curves = "../selected_results/mimic__Knapsack_10__curves.csv"
mimic__Knapsack_5__curves = "../selected_results/mimic__Knapsack_5__curves.csv"
mimic__TSP_22__curves = "../selected_results/mimic__TSP_22__curves.csv"
mimic__TSP_5__curves = "../selected_results/mimic__TSP_5__curves.csv"
mimic__Knapsack_10__curves = "../selected_results/mimic__Knapsack_10__curves.csv"
mimic__Knapsack_5__curves = "../selected_results/mimic__Knapsack_5__curves.csv"
rhc__Knapsack_10__curves = "../selected_results/rhc__Knapsack_10__curves.csv"
rhc__Knapsack_5__curves = "../selected_results/rhc__Knapsack_5__curves.csv"
rhc__TSP_22__curves = "../selected_results/rhc__TSP_22__curves.csv"
rhc__TSP_5__curves = "../selected_results/rhc__TSP_5__curves.csv"
rhc__Knapsack_10__curves = "../selected_results/rhc__Knapsack_10__curves.csv"
rhc__Knapsack_5__curves = "../selected_results/rhc__Knapsack_5__curves.csv"
sa__Knapsack_10__curves = "../selected_results/sa__Knapsack_10__curves.csv"
sa__Knapsack_5__curves = "../selected_results/sa__Knapsack_5__curves.csv"
sa__TSP_22__curves = "../selected_results/sa__TSP_22__curves.csv"
sa__TSP_5__curves = "../selected_results/sa__TSP_5__curves.csv"
sa__Knapsack_10__curves = "../selected_results/sa__Knapsack_10__curves.csv"
sa__Knapsack_5__curves = "../selected_results/sa__Knapsack_5__curves.csv"

# %%
ga__Knapsack_10_df = pd.read_csv(ga__Knapsack_10__curves, index_col="column0").reset_index(drop=True)
ga__Knapsack_5_df = pd.read_csv(ga__Knapsack_5__curves, index_col="column0").reset_index(drop=True)
ga__TSP_22_df = pd.read_csv(ga__TSP_22__curves, index_col="column0").reset_index(drop=True)
ga__TSP_5_df = pd.read_csv(ga__TSP_5__curves, index_col="column0").reset_index(drop=True)
ga__Knapsack_5_df = pd.read_csv(ga__Knapsack_5__curves, index_col="column0").reset_index(drop=True)
mimic__Knapsack_10_df = pd.read_csv(mimic__Knapsack_10__curves, index_col="column0").reset_index(drop=True)
mimic__Knapsack_5_df = pd.read_csv(mimic__Knapsack_5__curves, index_col="column0").reset_index(drop=True)
mimic__TSP_22_df = pd.read_csv(mimic__TSP_22__curves, index_col="column0").reset_index(drop=True)
mimic__TSP_5_df = pd.read_csv(mimic__TSP_5__curves, index_col="column0").reset_index(drop=True)
mimic__Knapsack_5_df = pd.read_csv(mimic__Knapsack_5__curves, index_col="column0").reset_index(drop=True)
rhc__Knapsack_10_df = pd.read_csv(rhc__Knapsack_10__curves, index_col="column0").reset_index(drop=True)
rhc__Knapsack_5_df = pd.read_csv(rhc__Knapsack_5__curves, index_col="column0").reset_index(drop=True)
rhc__TSP_22_df = pd.read_csv(rhc__TSP_22__curves, index_col="column0").reset_index(drop=True)
rhc__TSP_5_df = pd.read_csv(rhc__TSP_5__curves, index_col="column0").reset_index(drop=True)
rhc__Knapsack_5_df = pd.read_csv(rhc__Knapsack_5__curves, index_col="column0").reset_index(drop=True)
sa__Knapsack_10_df = pd.read_csv(sa__Knapsack_10__curves, index_col="column0").reset_index(drop=True)
sa__Knapsack_5_df = pd.read_csv(sa__Knapsack_5__curves, index_col="column0").reset_index(drop=True)
sa__TSP_22_df = pd.read_csv(sa__TSP_22__curves, index_col="column0").reset_index(drop=True)
sa__TSP_5_df = pd.read_csv(sa__TSP_5__curves, index_col="column0").reset_index(drop=True)
sa__Knapsack_5_df = pd.read_csv(sa__Knapsack_5__curves, index_col="column0").reset_index(drop=True)

# %%
sa__Knapsack_5_df['Fitness']
# Out:
# 0       177.0
# 1       169.0
# 2       166.0
# 3       172.0
# 4       140.0
#         ...
# 5708    207.0
# 5709    207.0
# 5710    207.0
# 5711    207.0
# 5712    207.0
# Name: Fitness, Length: 5713, dtype: float64

# %%
sa__ = "SA"
ga__ = "GA"
rhc__ = "RHC"
mimic__ = "MIMIC"

# %%
plt.figure()
lw = 1
plt.plot(rhc__Knapsack_5_df['Iteration'], rhc__Knapsack_5_df['Fitness'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__Knapsack_5_df['Iteration'], sa__Knapsack_5_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__Knapsack_5_df['Iteration'], ga__Knapsack_5_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__Knapsack_5_df['Iteration'], mimic__Knapsack_5_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Iteration')
plt.ylabel('Fitness')
plt.xlim(0,750)
plt.title("Knapsack (size=5)")
plt.legend(loc="lower right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__Knapsack_5_df['Iteration'], rhc__Knapsack_5_df['Fitness'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__Knapsack_5_df['Iteration'], sa__Knapsack_5_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__Knapsack_5_df['Iteration'], ga__Knapsack_5_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__Knapsack_5_df['Iteration'], mimic__Knapsack_5_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Iteration')
plt.ylabel('Fitness')
plt.xlim(0,30)
# plt.ylim(20,40)
plt.title("Knapsack - zoom (size=5)")
plt.legend(loc="lower right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__Knapsack_5_df['FEvals'], rhc__Knapsack_5_df['Fitness'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__Knapsack_5_df['FEvals'], sa__Knapsack_5_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__Knapsack_5_df['FEvals'], ga__Knapsack_5_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__Knapsack_5_df['FEvals'], mimic__Knapsack_5_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Function Evals')
plt.ylabel('Fitness')
# plt.xlim(0,4000)
# plt.ylim(20,40)
plt.title("Knapsack (size=5)")
plt.legend(loc="lower right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__Knapsack_5_df['FEvals'], rhc__Knapsack_5_df['Fitness'], label=rhc__, color='orange',lw=0.1)
plt.plot(sa__Knapsack_5_df['FEvals'], sa__Knapsack_5_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__Knapsack_5_df['FEvals'], ga__Knapsack_5_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__Knapsack_5_df['FEvals'], mimic__Knapsack_5_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Function Evals')
plt.ylabel('Fitness')
plt.xlim(0,3500)
plt.ylim(150,220)
plt.title("Knapsack F.Evals - zoom (size=5)")
plt.legend(loc="lower right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__Knapsack_5_df['Time'], rhc__Knapsack_5_df['Fitness'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__Knapsack_5_df[(sa__Knapsack_5_df['Time'] != 0)]['Time'], sa__Knapsack_5_df[(sa__Knapsack_5_df['Time'] != 0)]['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__Knapsack_5_df['Time'], ga__Knapsack_5_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__Knapsack_5_df['Time'], mimic__Knapsack_5_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Time')
plt.ylabel('Fitness')
plt.xlim(0,0.2)
plt.ylim(150,220)
plt.title("Knapsack Time - zoom (size=5)")
plt.legend(loc="lower right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__Knapsack_5_df['Time'], rhc__Knapsack_5_df['FEvals'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__Knapsack_5_df[(sa__Knapsack_5_df['Time'] != 0)]['Time'], sa__Knapsack_5_df[(sa__Knapsack_5_df['Time'] != 0)]['FEvals'], label=sa__, color='blue',lw=lw)
plt.plot(ga__Knapsack_5_df['Time'], ga__Knapsack_5_df['FEvals'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__Knapsack_5_df['Time'], mimic__Knapsack_5_df['FEvals'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Time')
plt.ylabel('Function Evals')
# plt.xlim(0,3)
# plt.ylim(0,5500)
plt.title("Knapsack F.Evals/Time (size=5)")
plt.legend(loc="lower right")

# %%
plt.figure()
lw = 1
plt.plot(rhc__Knapsack_10_df['FEvals'], rhc__Knapsack_10_df['Fitness'], label=rhc__, color='orange',lw=0.2)
plt.plot(sa__Knapsack_10_df['FEvals'], sa__Knapsack_10_df['Fitness'], label=sa__, color='blue',lw=lw)
plt.plot(ga__Knapsack_10_df['FEvals'], ga__Knapsack_10_df['Fitness'], label=ga__, color='darkgreen',lw=lw)
plt.plot(mimic__Knapsack_10_df['FEvals'], mimic__Knapsack_10_df['Fitness'], label=mimic__, color='purple',lw=lw)
#plt.plot([0, 0], [0, 0], color='white', lw=lw, linestyle='--')
plt.xlabel('Function Evals')
plt.ylabel('Fitness')
plt.xlim(0,20000)
plt.ylim(400,680)
plt.title("Knapsack F.Evals (size=10)")
plt.legend(loc="lower right")
